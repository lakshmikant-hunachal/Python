# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
data=["Lakshmikant","laxmi","pragathi","prashant"]
sr=pd.Series(data)
print(sr)
# Out:
# 0    Lakshmikant
# 1          laxmi
# 2       pragathi
# 3       prashant
# dtype: object

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\firstdata.csv")
print(df)
# Out:
#     1     PAWAN  8.9  8.9.1  7.5  8.9.2  7.5.1  8.9.3  8.5  8.6  67.7  8.9.4  \
# 0   2   KARTHIK  7.8    7.8  6.7    8.5    6.7    7.8  9.5  8.5  63.3    9.5
# 1   3     AKASH  6.5    9.5  8.6    8.6    8.6    9.5  8.9  9.5  69.7    9.5
# 2   4      MANU  9.8    9.8  9.5    8.6    9.5    9.8  7.8  8.9  73.7    9.8
# 3   5  MANUDEEP  8.5    8.5  9.9    8.9    9.9    8.5  9.5  7.8  71.5    9.9
# 4   6    KUSHAL  8.5    8.5  5.9    7.8    5.9    8.5  9.8  9.5  64.4    9.8
# 5   7     LAXMI  9.5    8.6  8.9    9.5    9.5    9.5  8.5  9.8  73.8    9.8
# 6   8      KANT  9.4    9.5  9.4    9.8    9.8    9.4  8.5  8.5  74.3    9.8
# 7   9     DEEPA  6.5    9.9  6.5    8.5    8.5    6.5  8.5  8.5  63.4    9.9
# 8  10    DEEPTI  8.0    5.9  8.4    8.5    8.5    8.0  9.5  8.6  65.4    9.5
#
#    7.5.2  8.4625  84.625   A   AVG
# 0    6.7  7.9125  79.125  B+   AVG
# 1    6.5  8.7125  87.125   A  GOOD
# 2    7.8  9.2125  92.125  A+  GOOD
# 3    7.8  8.9375  89.375   A  GOOD
# ...

# %%
student={
    "name":["lakshmikant","deepa","pragati","akash"],
    "marks":[89,98,78,98]
}
frame=pd.DataFrame(student)
frame
# Out:
#           name  marks
# 0  lakshmikant     89
# 1        deepa     98
# 2      pragati     78
# 3        akash     98

# %%
frame.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 frame.shape()
#
# TypeError: 'tuple' object is not callable

# %%
pd.shape(frame)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.shape(frame)
#
# AttributeError: module 'pandas' has no attribute 'shape'

# %%
frame.shape
# Out:
# (4, 2)

# %%
row,column=frame.shape
print(row)
print(column)
# Out:
# 4
# 2

# %%
frame.head()
# Out:
#           name  marks
# 0  lakshmikant     89
# 1        deepa     98
# 2      pragati     78
# 3        akash     98

# %%
frame.head(2)
# Out:
#           name  marks
# 0  lakshmikant     89
# 1        deepa     98

# %%
frame.tail(3)
# Out:
#       name  marks
# 1    deepa     98
# 2  pragati     78
# 3    akash     98

# %%
frame[]
# Out:
#   Cell In[15], line 1
#     frame[]
#           ^
# SyntaxError: invalid syntax

# %%
frame.name
# Out:
# 0    lakshmikant
# 1          deepa
# 2        pragati
# 3          akash
# Name: name, dtype: object

# %%
frame.marks
# Out:
# 0    89
# 1    98
# 2    78
# 3    98
# Name: marks, dtype: int64

# %%
frame[["name"]]
# Out:
#           name
# 0  lakshmikant
# 1        deepa
# 2      pragati
# 3        akash

# %%
type.frame["name"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 type.frame["name"]
#
# AttributeError: type object 'type' has no attribute 'frame'

# %%
frame["name"].type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30232\739202420.py in ?()
# ----> 1 frame["name"].type
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'type'

# %%
type(frame["name"])#always columns are series in pandas
# Out:
# pandas.core.series.Series

# %%
frame['marks'].max()
# Out:
# 98

# %%
frame.describe()
# Out:
#        marks
# count   4.00
# mean   90.75
# std     9.50
# min    78.00
# 25%    86.25
# 50%    93.50
# 75%    98.00
# max    98.00

# %%
frame.marks.min()
# Out:
# 78

# %%
frame.name.min()
# Out:
# 'akash'

# %%
frame.name.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 frame.name.mean()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# ...

# %%
frame.marks.mean()
# Out:
# np.float64(90.75)

# %%
fr=frame.set_index("name")#set index is create new dataframe not change the origin dataframe but when (index value,inplace=True) then it is change origin 
#origin dataframe

# %%
fr
# Out:
#              marks
# name
# lakshmikant     89
# deepa           98
# pragati         78
# akash           98

# %%
frame
# Out:
#           name  marks
# 0  lakshmikant     89
# 1        deepa     98
# 2      pragati     78
# 3        akash     98

# %%
frame.set_index("name",inplace=True)

# %%
frame
# Out:
#              marks
# name
# lakshmikant     89
# deepa           98
# pragati         78
# akash           98

# %%
frame.reset(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30232\2493517629.py in ?()
# ----> 1 frame.reset(inplace=True)
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'reset'

# %%
frame.reset_index(inplace=True)

# %%
frame
# Out:
#           name  marks
# 0  lakshmikant     89
# 1        deepa     98
# 2      pragati     78
# 3        akash     98

# %%
#type of the dataframe creation of the using many type data type 
#first using csv file (comma saparated value)
import pandas as pd
df1 = pd.read_csv(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\firstdata.csv")
df1
# Out:
#     1     PAWAN  8.9  8.9.1  7.5  8.9.2  7.5.1  8.9.3  8.5  8.6  67.7  8.9.4  \
# 0   2   KARTHIK  7.8    7.8  6.7    8.5    6.7    7.8  9.5  8.5  63.3    9.5
# 1   3     AKASH  6.5    9.5  8.6    8.6    8.6    9.5  8.9  9.5  69.7    9.5
# 2   4      MANU  9.8    9.8  9.5    8.6    9.5    9.8  7.8  8.9  73.7    9.8
# 3   5  MANUDEEP  8.5    8.5  9.9    8.9    9.9    8.5  9.5  7.8  71.5    9.9
# 4   6    KUSHAL  8.5    8.5  5.9    7.8    5.9    8.5  9.8  9.5  64.4    9.8
# 5   7     LAXMI  9.5    8.6  8.9    9.5    9.5    9.5  8.5  9.8  73.8    9.8
# 6   8      KANT  9.4    9.5  9.4    9.8    9.8    9.4  8.5  8.5  74.3    9.8
# 7   9     DEEPA  6.5    9.9  6.5    8.5    8.5    6.5  8.5  8.5  63.4    9.9
# 8  10    DEEPTI  8.0    5.9  8.4    8.5    8.5    8.0  9.5  8.6  65.4    9.5
#
#    7.5.2  8.4625  84.625   A   AVG
# 0    6.7  7.9125  79.125  B+   AVG
# 1    6.5  8.7125  87.125   A  GOOD
# 2    7.8  9.2125  92.125  A+  GOOD
# 3    7.8  8.9375  89.375   A  GOOD
# ...

# %%
#using excel file create dataframe
import pandas as pd

df2 = pd.read_excel(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\Book1.xlsx",sheet_name=2)
print(df2)
# Out:
#                 FULL NAME     FIRSTNAME   LASTNAME
# 0       karthik doddamani       karthik  doddamani
# 1             deepa nayak         deepa      nayak
# 2    lakshmikant hunachal   lakshmikant   hunachal
# 3         manudeepa hegde     manudeepa      hegde
# 4         savitri kalmani       savitri    kalmani
# 5            laxmi rathod         laxmi     rathod
# 6           anush kolakar         anush    kolakar
# 7       prashant hunachal      prashant   hunachal
# 8        pragati hunachal       pragati   hunachal
# 9          laxmi hunachal         laxmi   hunachal
# 10      nillamma hunachal      nillamma   hunachal
# 11  giramallappa hunachal  giramallappa   hunachal

# %%
df2.FIRSTNAME
# Out:
# 0          karthik
# 1            deepa
# 2      lakshmikant
# 3        manudeepa
# 4          savitri
# 5            laxmi
# 6            anush
# 7         prashant
# 8          pragati
# 9            laxmi
# 10        nillamma
# 11    giramallappa
# Name: FIRSTNAME, dtype: object

# %%
#create using dict
file={"name":["naveen","lakshmikant","deepa","karthik","gayatri","harini","pragati"],
      "age":[12,32,12,34,56,32,11],
      "date":[12,3,4,5,6,7,9]}
df3=pd.DataFrame(file)
df3
# Out:
#           name  age  date
# 0       naveen   12    12
# 1  lakshmikant   32     3
# 2        deepa   12     4
# 3      karthik   34     5
# 4      gayatri   56     6
# 5       harini   32     7
# 6      pragati   11     9

# %%
#create dataframe using list of tuples
file2=[("lakshmikant",19,89),
       ("laxmi",20,90),
       ("pragati",12,98),
       ("prashant",17,78),
       ("Savatri",19,99)]
df4=pd.DataFrame(file2,columns=["Name","Age","Marks"])#here column varible is option
df4
# Out:
#           Name  Age  Marks
# 0  lakshmikant   19     89
# 1        laxmi   20     90
# 2      pragati   12     98
# 3     prashant   17     78
# 4      Savatri   19     99

# %%
import pandas as pd

# Create DataFrame using list of dictionaries
file3 = [
    {"name": "lakshmikant", "Age": 19},
    {"name": "giramallappa", "Age": 40},
    {"name": "laxmi", "Age": 35}
]

df5 = pd.DataFrame(file3)

print(df5)
# Out:
#            name  Age
# 0   lakshmikant   19
# 1  giramallappa   40
# 2         laxmi   35

# %%
import pandas as pd
df6=pd.read_csv(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\Book1.csv",header=None,names=["NAMEE","AGEE","PLACEE"])
df6
# Out:
#          NAMEE AGEE        PLACEE
# 0        state  NaN           NaN
# 1         NAME  AGE         PLACE
# 2  lakshmikant   17     Bengaluru
# 3        deepa   15       Bijapur
# 4        laxmi   45         Gadag
# 5      karthik   65        Kodagu
# 6        kiran    3        Mandya
# 7       koshal   45      ramnagar
# 8       kamila   67  Basavanagudi
# 9    not found   43           n.a

# %%
#how to write to the csv file using to_csv method in pandas library
df6.to_csv("new_file.csv",header=False)

# %%
df6
# Out:
#          NAMEE AGEE        PLACEE
# 0        state  NaN           NaN
# 1         NAME  AGE         PLACE
# 2  lakshmikant   17     Bengaluru
# 3        deepa   15       Bijapur
# 4        laxmi   45         Gadag
# 5      karthik   65        Kodagu
# 6        kiran    3        Mandya
# 7       koshal   45      ramnagar
# 8       kamila   67  Basavanagudi
# 9    not found   43           n.a

# %%
import pandas as pd

def convert(cell):
    if cell == "la":
        return "Hunachal"
    return cell

df2 = pd.read_excel(
    r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\Book1.xlsx",
    sheet_name=2,
    converters={
        'LASTNAME': convert
    }
)

print(df2)
# Out:
#                 FULL NAME     FIRSTNAME   LASTNAME
# 0       karthik doddamani       karthik  doddamani
# 1             deepa nayak         deepa      nayak
# 2    lakshmikant hunachal   lakshmikant   hunachal
# 3         manudeepa hegde     manudeepa      hegde
# 4         savitri kalmani       savitri    kalmani
# 5            laxmi rathod         laxmi     rathod
# 6           anush kolakar         anush    kolakar
# 7       prashant hunachal      prashant   hunachal
# 8        pragati hunachal       pragati   hunachal
# 9          laxmi hunachal         laxmi   hunachal
# 10      nillamma hunachal      nillamma   hunachal
# 11  giramallappa hunachal  giramallappa   hunachal

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\bengaluru_weather.csv")
df
# Out:
#          Date  Temperature_C  Rain_Percentage
# 0  01-06-2025           28.0             60.0
# 1  02-06-2025           29.0              NaN
# 2  03-06-2025           27.0             80.0
# 3  04-06-2025            NaN              NaN
# 4  05-06-2025            NaN              NaN
# 5  06-06-2025           30.0             30.0
# 6         NaN           29.0             70.0
# 7  08-06-2025            NaN              NaN
# 8  09-06-2025           28.0             55.0
# 9  10-06-2025           29.0             45.0

# %%
#new_df=df.fillna(0) this is fill NaN value with 0 but this is method is not better there used interm of dict
#new_df=df.fillna({"Date":0,"Temperature_C":0,"Rain_Percentage":"No update"})
#above line fillna is not correct campare to other data therefore used fillna methods
new_df=df.fillna(method="ffill")
#ffill method is fill value before value in the table
new_df
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_12624\4022257745.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df=df.fillna(method="ffill")
#          Date  Temperature_C  Rain_Percentage
# 0  01-06-2025           28.0             60.0
# 1  02-06-2025           29.0             60.0
# 2  03-06-2025           27.0             80.0
# 3  04-06-2025           27.0             80.0
# 4  05-06-2025           27.0             80.0
# 5  06-06-2025           30.0             30.0
# 6  06-06-2025           29.0             70.0
# 7  08-06-2025           29.0             70.0
# 8  09-06-2025           28.0             55.0
# 9  10-06-2025           29.0             45.0

# %%
new_df=df.fillna(method="bfill")
new_df
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_12624\3832046755.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df=df.fillna(method="bfill")
#          Date  Temperature_C  Rain_Percentage
# 0  01-06-2025           28.0             60.0
# 1  02-06-2025           29.0             80.0
# 2  03-06-2025           27.0             80.0
# 3  04-06-2025           30.0             30.0
# 4  05-06-2025           30.0             30.0
# 5  06-06-2025           30.0             30.0
# 6  08-06-2025           29.0             70.0
# 7  08-06-2025           28.0             55.0
# 8  09-06-2025           28.0             55.0
# 9  10-06-2025           29.0             45.0

# %%
new_df=df.fillna(method="bfill",limit=1)
new_df
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_12624\3261593249.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df=df.fillna(method="bfill",limit=1)
#          Date  Temperature_C  Rain_Percentage
# 0  01-06-2025           28.0             60.0
# 1  02-06-2025           29.0             80.0
# 2  03-06-2025           27.0             80.0
# 3  04-06-2025            NaN              NaN
# 4  05-06-2025           30.0             30.0
# 5  06-06-2025           30.0             30.0
# 6  08-06-2025           29.0             70.0
# 7  08-06-2025           28.0             55.0
# 8  09-06-2025           28.0             55.0
# 9  10-06-2025           29.0             45.0

# %%
new_df=df.interpolate()
new_df
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_12624\1725489846.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df=df.interpolate()
#          Date  Temperature_C  Rain_Percentage
# 0  01-06-2025           28.0        60.000000
# 1  02-06-2025           29.0        70.000000
# 2  03-06-2025           27.0        80.000000
# 3  04-06-2025           28.0        63.333333
# 4  05-06-2025           29.0        46.666667
# 5  06-06-2025           30.0        30.000000
# 6         NaN           29.0        70.000000
# 7  08-06-2025           28.5        62.500000
# 8  09-06-2025           28.0        55.000000
# 9  10-06-2025           29.0        45.000000

# %%
new_df=df.dropna(thresh=2)
new_df
# Out:
#          Date  Temperature_C  Rain_Percentage
# 0  01-06-2025           28.0             60.0
# 1  02-06-2025           29.0              NaN
# 2  03-06-2025           27.0             80.0
# 5  06-06-2025           30.0             30.0
# 6         NaN           29.0             70.0
# 8  09-06-2025           28.0             55.0
# 9  10-06-2025           29.0             45.0

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\bengaluru_weather.csv")
df
# Out:
#          Date  Temperature_C  Rain_Percentage
# 0  01-06-2025             28               60
# 1  02-06-2025             29                0
# 2  03-06-2025             27               80
# 3  04-06-2025          -9999                0
# 4  05-06-2025          -9999                0
# 5  06-06-2025             30               30
# 6  07-06-2025             29               70
# 7  08-06-2025          -9999                0
# 8  09-06-2025             28               55
# 9  10-06-2025             29               45

# %%
#replace method replace the all special value with your value
import pandas as pd
import numpy as np

df=pd.read_csv(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\bengaluru_weather.csv")

new_df = df.replace([-9999, 0], np.nan)
print(new_df)
# Out:
#          Date  Temperature_C  Rain_Percentage
# 0  01-06-2025           28.0             60.0
# 1  02-06-2025           29.0              NaN
# 2  03-06-2025           27.0             80.0
# 3  04-06-2025            NaN              NaN
# 4  05-06-2025            NaN              NaN
# 5  06-06-2025           30.0             30.0
# 6  07-06-2025           29.0             70.0
# 7  08-06-2025            NaN              NaN
# 8  09-06-2025           28.0             55.0
# 9  10-06-2025           29.0             45.0

# %%
new_df=df.replace({"Temperature_C":-9999,
                   "Rain_Percentage":0},np.nan)
new_df
# Out:
#          Date  Temperature_C  Rain_Percentage
# 0  01-06-2025           28.0             60.0
# 1  02-06-2025           29.0              NaN
# 2  03-06-2025           27.0             80.0
# 3  04-06-2025            NaN              NaN
# 4  05-06-2025            NaN              NaN
# 5  06-06-2025           30.0             30.0
# 6  07-06-2025           29.0             70.0
# 7  08-06-2025            NaN              NaN
# 8  09-06-2025           28.0             55.0
# 9  10-06-2025           29.0             45.0

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\city_weather_dataset.csv")
df
# Out:
#          Date       City             Area  Temperature_C  WindSpeed_kmph
# 0  2025-06-01  Bengaluru       Whitefield             28              12
# 1  2025-06-01  Bengaluru        Jayanagar             27              10
# 2  2025-06-01  Bengaluru  Electronic City             29              14
# 3  2025-06-01     Mysuru      Vijayanagar             31              11
# 4  2025-06-01     Mysuru         Nazarbad             30               9
# 5  2025-06-01     Mysuru           Hebbal             32              13
# 6  2025-06-01  Mangaluru            Kadri             29              18
# 7  2025-06-01  Mangaluru        Surathkal             30              20
# 8  2025-06-01  Mangaluru         Panambur             28              17

# %%
g = df.groupby("City")

print(g)
for city,city_df in g:
    print(city)
    print(city_df)
# Out:
# ...
# Bengaluru
#          Date       City             Area  Temperature_C  WindSpeed_kmph
# 0  2025-06-01  Bengaluru       Whitefield             28              12
# 1  2025-06-01  Bengaluru        Jayanagar             27              10
# 2  2025-06-01  Bengaluru  Electronic City             29              14
# Mangaluru
#          Date       City       Area  Temperature_C  WindSpeed_kmph
# 6  2025-06-01  Mangaluru      Kadri             29              18
# 7  2025-06-01  Mangaluru  Surathkal             30              20
# 8  2025-06-01  Mangaluru   Panambur             28              17
# Mysuru
#          Date    City         Area  Temperature_C  WindSpeed_kmph
# 3  2025-06-01  Mysuru  Vijayanagar             31              11
# 4  2025-06-01  Mysuru     Nazarbad             30               9
# 5  2025-06-01  Mysuru       Hebbal             32              13

# %%
print(g.max())
# Out:
#                  Date         Area  Temperature_C  WindSpeed_kmph
# City
# Bengaluru  2025-06-01   Whitefield             29              14
# Mangaluru  2025-06-01    Surathkal             30              20
# Mysuru     2025-06-01  Vijayanagar             32              13

# %%
import matplotlib.pyplot as plt
g.plot()
# Out:
# City
# Bengaluru    Axes(0.125,0.11;0.775x0.77)
# Mangaluru    Axes(0.125,0.11;0.775x0.77)
# Mysuru       Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
import numpy as np
import pandas as pd
#create series using array 
arr=np.array([1,2,3,4,5])
series=pd.Series(arr)
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#create series using dectonary 
dic={"Lakshmikant":90,"deepa":89,"pragati":99}
s=pd.Series(dic)
print(s)
# Out:
# Lakshmikant    90
# deepa          89
# pragati        99
# dtype: int64

# %%
name=["lakshmikant","deepa","laxmi","savitri","pragati","prashant"]
index=[11,12,13,14,15,16]
s=pd.Series(name,index=index)
print(s)
# Out:
# 11    lakshmikant
# 12          deepa
# 13          laxmi
# 14        savitri
# 15        pragati
# 16       prashant
# dtype: object

# %%
import pandas as pd
df1=pd.DataFrame({
    "city":["vijayapur","Nandihal","B.Bagewadi"],
    "temp":[34,35,35],
    "humidity":[80,78,89]
})
df1
# Out:
#          city  temp  humidity
# 0   vijayapur    34        80
# 1    Nandihal    35        78
# 2  B.Bagewadi    35        89

# %%
df2=pd.DataFrame({"city":["bagalakote","ilakal","jamakandi"],
                  "temp":[36,37,40],
                  "humidity":[86,88,92]})
df2
# Out:
#          city  temp  humidity
# 0  bagalakote    36        86
# 1      ilakal    37        88
# 2   jamakandi    40        92

# %%
df=pd.concat([df1,df2])
df
# Out:
#          city  temp  humidity
# 0   vijayapur    34        80
# 1    Nandihal    35        78
# 2  B.Bagewadi    35        89
# 0  bagalakote    36        86
# 1      ilakal    37        88
# 2   jamakandi    40        92

# %%
#do index is continous 
df=pd.concat([df1,df2],ignore_index=True)
df
# Out:
#          city  temp  humidity
# 0   vijayapur    34        80
# 1    Nandihal    35        78
# 2  B.Bagewadi    35        89
# 3  bagalakote    36        86
# 4      ilakal    37        88
# 5   jamakandi    40        92

# %%
#applied key value
df=pd.concat([df1,df2],keys=["vijayapur","bagalakote"])
df
# Out:
#                     city  temp  humidity
# vijayapur  0   vijayapur    34        80
#            1    Nandihal    35        78
#            2  B.Bagewadi    35        89
# bagalakote 0  bagalakote    36        86
#            1      ilakal    37        88
#            2   jamakandi    40        92

# %%
df.loc["vijayapur"]
# Out:
#          city  temp  humidity
# 0   vijayapur    34        80
# 1    Nandihal    35        78
# 2  B.Bagewadi    35        89

# %%
df.loc["bagalakote"]
# Out:
#          city  temp  humidity
# 0  bagalakote    36        86
# 1      ilakal    37        88
# 2   jamakandi    40        92

# %%
#add two and more than dataframe in the form of the row and now we are studies 
#add in the form of the column
df1=pd.DataFrame({"city":["bagalakote","ilakal","jamakandi"],
                  "temp":[36,37,40],})
df1
# Out:
#          city  temp
# 0  bagalakote    36
# 1      ilakal    37
# 2   jamakandi    40

# %%
df2=pd.DataFrame({"city":["bagalakote","ilakal","jamakandi"],
                  "humidity":[86,88,92]})
df2
# Out:
#          city  humidity
# 0  bagalakote        86
# 1      ilakal        88
# 2   jamakandi        92

# %%
df=pd.concat([df1,df2])
df
#this method is not correct threre fore axis is defaulty value is 0
# Out:
#          city  temp  humidity
# 0  bagalakote  36.0       NaN
# 1      ilakal  37.0       NaN
# 2   jamakandi  40.0       NaN
# 0  bagalakote   NaN      86.0
# 1      ilakal   NaN      88.0
# 2   jamakandi   NaN      92.0

# %%
df=pd.concat([df1,df2],axis=1)
df
# Out:
#          city  temp        city  humidity
# 0  bagalakote    36  bagalakote        86
# 1      ilakal    37      ilakal        88
# 2   jamakandi    40   jamakandi        92

# %%
#in some condition index of the any city values are differnt in datafrme then
df1=pd.DataFrame({"city":["bagalakote","ilakal","jamakandi"],
                  "temp":[36,37,40],})
df1
# Out:
#          city  temp
# 0  bagalakote    36
# 1      ilakal    37
# 2   jamakandi    40

# %%
df2=pd.DataFrame({"city":["bagalakote","jamakandi","ilakal"],
                  "humidity":[86,92,88]})
df2
# Out:
#          city  humidity
# 0  bagalakote        86
# 1   jamakandi        92
# 2      ilakal        88

# %%
df=pd.concat([df1,df2],axis=1)
df
# Out:
#          city  temp        city  humidity
# 0  bagalakote    36  bagalakote        86
# 1      ilakal    37   jamakandi        92
# 2   jamakandi    40      ilakal        88

# %%
#see about output cities names are not correct match there fore add index key during
#dataframe creation
df1=pd.DataFrame({"city":["bagalakote","ilakal","jamakandi"],
                  "temp":[36,37,40],},index=[0,1,2])
print(df1)
df2=pd.DataFrame({"city":["bagalakote","jamakandi","ilakal"],
                  "humidity":[86,92,88]},index=[0,2,1])
print(df2)
df=pd.concat([df1,df2],axis=1)
df
# Out:
#          city  temp
# 0  bagalakote    36
# 1      ilakal    37
# 2   jamakandi    40
#          city  humidity
# 0  bagalakote        86
# 2   jamakandi        92
# 1      ilakal        88
#          city  temp        city  humidity
# 0  bagalakote    36  bagalakote        86
# 1      ilakal    37      ilakal        88
# 2   jamakandi    40   jamakandi        92

# %%
#concatation of two dataframe using merge differance between merge and concat method merge method is remove the same columns
df1=pd.DataFrame({"city":["bagalakote","ilakal","jamakandi"],
                  "temp":[36,37,40],})
df2=pd.DataFrame({"city":["bagalakote","jamakandi","ilakal"],
                  "humidity":[86,92,88]})
df=pd.merge(df1,df2,on="city")
df
# Out:
#          city  temp  humidity
# 0  bagalakote    36        86
# 1      ilakal    37        88
# 2   jamakandi    40        92

# %%
#add some different cities name to the both dataframe
df1=pd.DataFrame({"city":["bagalakote","ilakal","jamakandi","navanagar"],
                  "temp":[36,37,40,45],})
df2=pd.DataFrame({"city":["bagalakote","jamakandi","ilakal","vijayapur"],
                  "humidity":[86,92,88,89]})
df=pd.merge(df1,df2,on="city",how="inner")
df
#default how value is inner join
# Out:
#          city  temp  humidity
# 0  bagalakote    36        86
# 1      ilakal    37        88
# 2   jamakandi    40        92

# %%
df1=pd.DataFrame({"city":["bagalakote","ilakal","jamakandi","navanagar"],
                  "temp":[36,37,40,45],})
df2=pd.DataFrame({"city":["bagalakote","jamakandi","ilakal","vijayapur"],
                  "humidity":[86,92,88,89]})
df=pd.merge(df1,df2,on="city",how="outer")
df
#outer join means union function
# Out:
#          city  temp  humidity
# 0  bagalakote  36.0      86.0
# 1      ilakal  37.0      88.0
# 2   jamakandi  40.0      92.0
# 3   navanagar  45.0       NaN
# 4   vijayapur   NaN      89.0

# %%
df1=pd.DataFrame({"city":["bagalakote","ilakal","jamakandi","navanagar"],
                  "temp":[36,37,40,45],})
df2=pd.DataFrame({"city":["bagalakote","jamakandi","ilakal","vijayapur"],
                  "humidity":[86,92,88,89]})
df=pd.merge(df1,df2,on="city",how="left")
df
#left join works on the how we will passes to the merge
# Out:
#          city  temp  humidity
# 0  bagalakote    36      86.0
# 1      ilakal    37      88.0
# 2   jamakandi    40      92.0
# 3   navanagar    45       NaN

# %%
df1=pd.DataFrame({"city":["bagalakote","ilakal","jamakandi","navanagar"],
                  "temp":[36,37,40,45],})
df2=pd.DataFrame({"city":["bagalakote","jamakandi","ilakal","vijayapur"],
                  "humidity":[86,92,88,89]})
df=pd.merge(df1,df2,on="city",how="right")
df
#right join same as left
# Out:
#          city  temp  humidity
# 0  bagalakote  36.0        86
# 1   jamakandi  40.0        92
# 2      ilakal  37.0        88
# 3   vijayapur   NaN        89

# %%
#pivot method it is help for translate and redemition of the table structure
import pandas as pd
df=pd.read_csv(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\Data.csv")
print(df)
df1=df.pivot(index="Date",columns="City")
df1
# Out:
#          Date       City  Humidity  Temp
# 0  01-06-2026  bengaluru        85    34
# 1  02-06-2026  bengaluru        96    35
# 2  03-06-2026  bengaluru        45    36
# 3  01-06-2026     mysore        74    40
# 4  02-06-2026     mysore        85    41
# 5  03-06-2026     mysore        96    39
# 6  01-06-2026  vijayapur        56    42
# 7  02-06-2026  vijayapur        65    41
# 8  03-06-2026  vijayapur        58    45
#             Humidity                       Temp
# City       bengaluru mysore vijayapur bengaluru mysore vijayapur
# Date
# 01-06-2026        85     74        56        34     40        42
# 02-06-2026        96     85        65        35     41        41
# 03-06-2026        45     96        58        36     39        45

# %%
df1=df.pivot(index="Date",columns="City",values="Humidity")
df1
# Out:
# City        bengaluru  mysore  vijayapur
# Date
# 01-06-2026         85      74         56
# 02-06-2026         96      85         65
# 03-06-2026         45      96         58

# %%
df1=df.pivot(index="City",columns="Date")
df1
# Out:
#             Humidity                             Temp
# Date      01-06-2026 02-06-2026 03-06-2026 01-06-2026 02-06-2026 03-06-2026
# City
# bengaluru         85         96         45         34         35         36
# mysore            74         85         96         40         41         39
# vijayapur         56         65         58         42         41         45

# %%
print(df1)
# Out:
#             Humidity                             Temp
# Date      01-06-2026 02-06-2026 03-06-2026 01-06-2026 02-06-2026 03-06-2026
# City
# bengaluru         85         96         45         34         35         36
# mysore            74         85         96         40         41         39
# vijayapur         56         65         58         42         41         45

# %%
df=pd.read_csv(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\Data.csv")
print(df)
# Out:
#          Date       City  Humidity  Temp
# 0  01-06-2026  bengaluru        85    34
# 1  01-06-2026  bengaluru        96    35
# 2  01-06-2026  bengaluru        45    36
# 3  01-06-2026     mysore        74    40
# 4  01-06-2026     mysore        85    41
# 5  01-06-2026     mysore        96    39
# 6  01-06-2026  vijayapur        56    42
# 7  01-06-2026  vijayapur        65    41
# 8  01-06-2026  vijayapur        58    45

# %%
#pivot table used for find oaggrigate functions
df1=df.pivot_table(index="City",columns="Date")
df1
# Out:
#             Humidity       Temp
# Date      01-06-2026 01-06-2026
# City
# bengaluru  75.333333  35.000000
# mysore     85.000000  40.000000
# vijayapur  59.666667  42.666667

# %%
df=pd.read_csv(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\Book.csv")
print(df)
# Out:
#          Day  Bengaluru  Mysore  tumakur
# 0     Sunday         41      39       23
# 1     Monday         40      40       32
# 2    Tuesday         52      38       25
# 3  Wednesday         41      39       27
# 4   Thursday         42      36       28
# 5     Friday         43      23       29
# 6   Saturday         40      34       30

# %%
df
# Out:
#          Day  Bengaluru  Mysore  tumakur
# 0     Sunday         41      39       23
# 1     Monday         40      40       32
# 2    Tuesday         52      38       25
# 3  Wednesday         41      39       27
# 4   Thursday         42      36       28
# 5     Friday         43      23       29
# 6   Saturday         40      34       30

# %%
pd.melt(df,id_vars="Day")
# Out:
#           Day   variable  value
# 0      Sunday  Bengaluru     41
# 1      Monday  Bengaluru     40
# 2     Tuesday  Bengaluru     52
# 3   Wednesday  Bengaluru     41
# 4    Thursday  Bengaluru     42
# 5      Friday  Bengaluru     43
# 6    Saturday  Bengaluru     40
# 7      Sunday     Mysore     39
# 8      Monday     Mysore     40
# 9     Tuesday     Mysore     38
# 10  Wednesday     Mysore     39
# 11   Thursday     Mysore     36
# 12     Friday     Mysore     23
# 13   Saturday     Mysore     34
# 14     Sunday    tumakur     23
# 15     Monday    tumakur     32
# 16    Tuesday    tumakur     25
# 17  Wednesday    tumakur     27
# 18   Thursday    tumakur     28
# 19     Friday    tumakur     29
# 20   Saturday    tumakur     30

# %%
pd.melt(df,id_vars="Day",var_name="City",value_name="Temp")
# Out:
#           Day       City  Temp
# 0      Sunday  Bengaluru    41
# 1      Monday  Bengaluru    40
# 2     Tuesday  Bengaluru    52
# 3   Wednesday  Bengaluru    41
# 4    Thursday  Bengaluru    42
# 5      Friday  Bengaluru    43
# 6    Saturday  Bengaluru    40
# 7      Sunday     Mysore    39
# 8      Monday     Mysore    40
# 9     Tuesday     Mysore    38
# 10  Wednesday     Mysore    39
# 11   Thursday     Mysore    36
# 12     Friday     Mysore    23
# 13   Saturday     Mysore    34
# 14     Sunday    tumakur    23
# 15     Monday    tumakur    32
# 16    Tuesday    tumakur    25
# 17  Wednesday    tumakur    27
# 18   Thursday    tumakur    28
# 19     Friday    tumakur    29
# 20   Saturday    tumakur    30

# %%
#stack method reshape the table or data table
import pandas as pd

data = {
    ('Price', 'Facebook'): [155,150,153,155,156],
    ('Price', 'Google'): [955,987,963,1000,1012],
    ('Price', 'Microsoft'): [66,69,62,61,66],
    ('P/E Ratio', 'Facebook'): [37.10,36.98,36.78,36.11,37.07],
    ('P/E Ratio', 'Google'): [32.0,31.3,31.7,31.2,30.0],
    ('P/E Ratio', 'Microsoft'): [30.31,30.56,30.46,30.11,31.00]
}

index = ['2017-06-05','2017-06-06','2017-06-07','2017-06-08','2017-06-09']

df = pd.DataFrame(data, index=index)

df.to_csv(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\company_stock_data.csv")

print("CSV file created successfully")
# Out:
# CSV file created successfully

# %%
import pandas as pd

df = pd.read_csv(
    r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\company_stock_data.csv",
    header=[0,1],
    index_col=0
)

print(df)
# Out:
#               Price                  P/E Ratio
#            Facebook Google Microsoft  Facebook Google Microsoft
# 2017-06-05      155    955        66     37.10   32.0     30.31
# 2017-06-06      150    987        69     36.98   31.3     30.56
# 2017-06-07      153    963        62     36.78   31.7     30.46
# 2017-06-08      155   1000        61     36.11   31.2     30.11
# 2017-06-09      156   1012        66     37.07   30.0     31.00

# %%
df.stack()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_18208\3977694045.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack()
#                       Price  P/E Ratio
# 2017-06-05 Facebook     155      37.10
#            Google       955      32.00
#            Microsoft     66      30.31
# 2017-06-06 Facebook     150      36.98
#            Google       987      31.30
#            Microsoft     69      30.56
# 2017-06-07 Facebook     153      36.78
#            Google       963      31.70
#            Microsoft     62      30.46
# 2017-06-08 Facebook     155      36.11
#            Google      1000      31.20
#            Microsoft     61      30.11
# 2017-06-09 Facebook     156      37.07
#            Google      1012      30.00
#            Microsoft     66      31.00

# %%
df.stack(level=0) #level means header name in the  table or data table
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_18208\4116294391.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df.stack(level=0)
#                       Facebook  Google  Microsoft
# 2017-06-05 P/E Ratio     37.10    32.0      30.31
#            Price        155.00   955.0      66.00
# 2017-06-06 P/E Ratio     36.98    31.3      30.56
#            Price        150.00   987.0      69.00
# 2017-06-07 P/E Ratio     36.78    31.7      30.46
#            Price        153.00   963.0      62.00
# 2017-06-08 P/E Ratio     36.11    31.2      30.11
#            Price        155.00  1000.0      61.00
# 2017-06-09 P/E Ratio     37.07    30.0      31.00
#            Price        156.00  1012.0      66.00

# %%
df1=df.stack()
df1
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_18208\83334390.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df1=df.stack()
#                       Price  P/E Ratio
# 2017-06-05 Facebook     155      37.10
#            Google       955      32.00
#            Microsoft     66      30.31
# 2017-06-06 Facebook     150      36.98
#            Google       987      31.30
#            Microsoft     69      30.56
# 2017-06-07 Facebook     153      36.78
#            Google       963      31.70
#            Microsoft     62      30.46
# 2017-06-08 Facebook     155      36.11
#            Google      1000      31.20
#            Microsoft     61      30.11
# 2017-06-09 Facebook     156      37.07
#            Google      1012      30.00
#            Microsoft     66      31.00

# %%
#unstack means convert stack table into origin shape
df2=df1.unstack()
df2
# Out:
#               Price                  P/E Ratio
#            Facebook Google Microsoft  Facebook Google Microsoft
# 2017-06-05      155    955        66     37.10   32.0     30.31
# 2017-06-06      150    987        69     36.98   31.3     30.56
# 2017-06-07      153    963        62     36.78   31.7     30.46
# 2017-06-08      155   1000        61     36.11   31.2     30.11
# 2017-06-09      156   1012        66     37.07   30.0     31.00

# %%
df=pd.read_excel(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\Book.xlsx")
df
# Out:
#        Name Nationality  Age     Sex Handless
# 0      kant       india   24    male     left
# 1     laxmi       india   21  female     left
# 2    janaki       india   52  female    right
# 3     jaana       india   25    male     left
# 4     akash         USA   32    male    right
# 5   karthik         USA   12    male    right
# 6     manoj         USA   45    male    right
# 7     karan      Canada   41    male     left
# 8     deepa      Canada   42  female    right
# 9   gayatri      Canada   45  female     left
# 10     manu      Canada   25    male    right

# %%
df1=pd.crosstab(df.Nationality,df.Handless,margins=True)
df1
# Out:
# Handless     left  right  All
# Nationality
# Canada          2      2    4
# USA             0      3    3
# india           3      1    4
# All             5      6   11

# %%
df1=pd.crosstab(df.Sex,[df.Handless,df.Nationality],margins=True)
df1
# Out:
# Handless      left        right           All
# Nationality Canada india Canada USA india
# Sex
# female           1     1      1   0     1   4
# male             1     2      1   3     0   7
# All              2     3      2   3     1  11

# %%
df = pd.read_excel(
    r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\banana_price_1year.xlsx",
    parse_dates=["Date"],
    index_col="Date"
)

print(type(df.index))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
df["2024-01-01":"2024-01-11"]
# Out:
#              Open   High    Low  Close  Volume
# Date
# 2024-01-01  50.14  50.89  49.81  50.01   18692
# 2024-01-02  49.35  50.23  48.47  48.75   28166
# 2024-01-03  48.93  49.25  48.62  49.19   31642
# 2024-01-04  49.00  49.97  48.12  49.24   20057
# 2024-01-05  49.20  50.27  47.80  50.18   13710
# 2024-01-06  50.19  50.85  49.34  49.96   19404
# 2024-01-07  49.26  50.40  48.09  49.13   10994
# 2024-01-08  49.82  50.13  49.14  49.46   24376
# 2024-01-09  48.90  49.03  47.82  48.60   12964
# 2024-01-10  48.73  49.24  48.53  48.95   33806
# 2024-01-11  48.33  49.53  47.94  49.16   18311

# %% [markdown]
# df2=df.Close.resample('M').mean()
# df

# %%
df.Close.resample('M').mean()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_18664\3510564528.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.Close.resample('M').mean()
# Date
# 2024-01-31    49.386452
# 2024-02-29    49.264138
# 2024-03-31    48.939677
# 2024-04-30    48.904333
# 2024-05-31    47.654194
# 2024-06-30    46.269667
# 2024-07-31    49.003548
# 2024-08-31    54.941935
# 2024-09-30    59.346333
# 2024-10-31    58.305484
# 2024-11-30    62.193667
# 2024-12-31    58.630333
# Freq: ME, Name: Close, dtype: float64

# %%
#plot datatimeindex
import matplotlib as plt
# %matplotlib inline
df.Close.resample('Q').mean().plot()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_18664\3337262623.py:4: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.Close.resample('Q').mean().plot()
# <Axes: xlabel='Date'>

# %%
df.plot(kind="bar")
plt.show()

# %%
import matplotlib.pyplot as plt

df.plot(figsize=(10,6))

plt.title("Banana Historical Data")
plt.xlabel("Date")
plt.ylabel("Amount")

plt.show()

# %%
import matplotlib as plt
# %matplotlib inline
df.Close.resample('M').mean().plot(kind="bar")
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_18664\362895942.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.Close.resample('M').mean().plot(kind="bar")
# <Axes: xlabel='Date'>

# %%
import matplotlib as plt
# %matplotlib inline
df.Close.resample('Q').mean().plot(kind="pie")
plt.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_18664\64813632.py:3: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.Close.resample('Q').mean().plot(kind="pie")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 4
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 df.Close.resample('Q').mean().plot(kind="pie")
# ----> 4 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
# C:\Users\laksh\AppData\Local\Temp\ipykernel_18664\939912909.py:3: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df.Close.resample('Q').mean().plot(kind="boxplot")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 3
#       1 import matplotlib as plt
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 3 df.Close.resample('Q').mean().plot(kind="boxplot")

# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_core.py:960, in PlotAccessor.__call__(self, *args, **kwargs)
#     957     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     959 if kind not in self._all_kinds:
# --> 960     raise ValueError(
#     961         f"{kind} is not a valid plot kind "
#     962         f"Valid plot kinds: {self._all_kinds}"
#     963     )
#     965 # The original data structured can be transformed before passed to the
#     966 # backend. For example, for DataFrame is common to set the index as the
#     967 # `x` parameter, and return a Series with the parameter `y` as values.
#     968 data = self._parent.copy()

# ValueError: boxplot is not a valid plot kind Valid plot kinds: ('line', 'bar', 'barh', 'kde', 'density', 'area', 'hist', 'box', 'pie', 'scatter', 'hexbin')

# %%
import pandas as pd
d={"Name":['ram','sham','veer','pawan'],
   'Age':[14,52,24,35],
   'city':['Bengaluru','mysore','vijayapur','mandya']
  }
df=pd.DataFrame(d)
df
# Out:
#     Name  Age       city
# 0    ram   14  Bengaluru
# 1   sham   52     mysore
# 2   veer   24  vijayapur
# 3  pawan   35     mandya

# %%
df["Name"]
# Out:
# 0      ram
# 1     sham
# 2     veer
# 3    pawan
# Name: Name, dtype: object

# %%
df.iloc[0][0]
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_10328\2900375399.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][0]
# 'ram'

# %%
df["Salary"]=[45000,50000,85000,56000]
df
# Out:
#     Name  Age       city  Salary
# 0    ram   14  Bengaluru   45000
# 1   sham   52     mysore   50000
# 2   veer   24  vijayapur   85000
# 3  pawan   35     mandya   56000

# %%
df
# Out:
#     Name  Age       city
# 0    ram   14  Bengaluru
# 1   sham   52     mysore
# 2   veer   24  vijayapur
# 3  pawan   35     mandya

# %%
df
# Out:
#     Name  Age       city  Salary
# 0    ram   14  Bengaluru   45000
# 1   sham   52     mysore   50000
# 2   veer   24  vijayapur   85000
# 3  pawan   35     mandya   56000

# %%
df
# Out:
#     Name  Age       city
# 0    ram   14  Bengaluru
# 1   sham   52     mysore
# 2   veer   24  vijayapur
# 3  pawan   35     mandya

# %%
import pandas as pd
df1 = pd.read_csv(r"C:\Users\laksh\OneDrive\Desktop\Goal\EXCEL\firstdata.csv")
df1
# Out:
#     1     PAWAN  8.9  8.9.1  7.5  8.9.2  7.5.1  8.9.3  8.5  8.6  67.7  8.9.4  \
# 0   2   KARTHIK  7.8    7.8  6.7    8.5    6.7    7.8  9.5  8.5  63.3    9.5
# 1   3     AKASH  6.5    9.5  8.6    8.6    8.6    9.5  8.9  9.5  69.7    9.5
# 2   4      MANU  9.8    9.8  9.5    8.6    9.5    9.8  7.8  8.9  73.7    9.8
# 3   5  MANUDEEP  8.5    8.5  9.9    8.9    9.9    8.5  9.5  7.8  71.5    9.9
# 4   6    KUSHAL  8.5    8.5  5.9    7.8    5.9    8.5  9.8  9.5  64.4    9.8
# 5   7     LAXMI  9.5    8.6  8.9    9.5    9.5    9.5  8.5  9.8  73.8    9.8
# 6   8      KANT  9.4    9.5  9.4    9.8    9.8    9.4  8.5  8.5  74.3    9.8
# 7   9     DEEPA  6.5    9.9  6.5    8.5    8.5    6.5  8.5  8.5  63.4    9.9
# 8  10    DEEPTI  8.0    5.9  8.4    8.5    8.5    8.0  9.5  8.6  65.4    9.5
#
#    7.5.2  8.4625  84.625   A   AVG
# 0    6.7  7.9125  79.125  B+   AVG
# 1    6.5  8.7125  87.125   A  GOOD
# 2    7.8  9.2125  92.125  A+  GOOD
# 3    7.8  8.9375  89.375   A  GOOD
# ...

# %%
df1.isnull()
# Out:
#        1  PAWAN    8.9  8.9.1    7.5  8.9.2  7.5.1  8.9.3    8.5    8.6  \
# 0  False  False  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False  False  False  False
# 2  False  False  False  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False  False  False  False
# 4  False  False  False  False  False  False  False  False  False  False
# 5  False  False  False  False  False  False  False  False  False  False
# 6  False  False  False  False  False  False  False  False  False  False
# 7  False  False  False  False  False  False  False  False  False  False
# 8  False  False  False  False  False  False  False  False  False  False
#
#     67.7  8.9.4  7.5.2  8.4625  84.625      A    AVG
# 0  False  False  False   False   False  False  False
# 1  False  False  False   False   False  False  False
# 2  False  False  False   False   False  False  False
# ...

# %%
df1.isnull().any()
# Out:
# 1         False
# PAWAN     False
# 8.9       False
# 8.9.1     False
# 7.5       False
# 8.9.2     False
# 7.5.1     False
# 8.9.3     False
# 8.5       False
# 8.6       False
# 67.7      False
# 8.9.4     False
# 7.5.2     False
# 8.4625    False
# 84.625    False
# A         False
# AVG       False
# dtype: bool

# %%
df1.isnull().any().mean()
# Out:
# np.float64(0.0)

# %%
df1.isnull()
